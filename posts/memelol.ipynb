# %% [markdown]
# memelol
#
# http://version1.api.memegenerator.net/Instances_Select_ByPopular?languageCode=en&pageIndex=0&pageSize=24&urlName=Insanity-Wolf&days=365
#
# Download popular meme. Edit images and text with PIL

# %%
import requests
import nltk
import getpass
import random
import PIL
from PIL import ImageDraw, ImageFont
import shutil
from IPython.display import Image
from IPython.core.display import HTML

# %%
myusr = getpass.getuser()

# %%
mepat = ('/home/{}/memetemp/'.format(myusr))

# %%
reqmempop = requests.get('http://version1.api.memegenerator.net/Generators_Select_ByPopular?pageIndex=0&pageSize=24')

# %%
genres = reqmempop.json()

# %%
for ger in genres['result']:
    #print(ger)
    response = requests.get(ger['imageUrl'], stream=True)
    namimg = ger['urlName']
    #print(len(namimg))
    #print(namimg)
    with open('{}{}.jpg'.format(mepat, namimg), 'wb') as out_file:
        shutil.copyfileobj(response.raw, out_file)
        del response
        
    meing = PIL.Image.open('{}{}.jpg'.format(mepat, namimg))
    #meing
    medraw = ImageDraw.Draw(meing)
    #font = ImageFont.truetype("/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf", 32)
    #font = ImageFont.truetype("/home/wcm/Downloads/fashi954.ttf", 12)
    fontwo = ImageFont.truetype('/usr/share/fonts/truetype/dejavu/DejaVuSansMono.ttf', 48)

    medraw.text((10, 10), namimg, (255,0,0), font=fontwo)
    
    meing.save('{}{}.jpg'.format(mepat, namimg))
# Out:
# {'generatorID': 2, 'urlName': 'Y-U-No', 'imageID': 166088, 'displayName': 'Y U No', 'imageUrl': 'https://cdn.meme.am/cache/images/folder88/400x/166088.jpg', 'totalVotesScore': 9290, 'ranking': 1, 'instancesCount': 2253169}
# 6
# Y-U-No
# {'generatorID': 305, 'urlName': 'Futurama-Fry', 'imageID': 84688, 'displayName': 'Futurama Fry', 'imageUrl': 'https://cdn.meme.am/cache/images/folder688/400x/84688.jpg', 'totalVotesScore': 6388, 'ranking': 2, 'instancesCount': 1580698}
# 12
# Futurama-Fry
# {'generatorID': 74, 'urlName': 'The-Most-Interesting-Man-In-The-World', 'imageID': 2485, 'displayName': 'The Most Interesting Man In The World', 'imageUrl': 'https://cdn.meme.am/cache/images/folder485/400x/2485.jpg', 'totalVotesScore': 4957, 'ranking': 3, 'instancesCount': 1849842}
# 37
# The-Most-Interesting-Man-In-The-World
# ...

# %%
selpo = ('http://version1.api.memegenerator.net/Instances_Select_ByPopular?')

# %%
#reqinst = requests.get('{}languageCode=en&pageIndex=0&pageSize=1&urlName={}'.format(selpogenres['result'][gere]['displayName']))

# %%
disnam = list()

# %%
ranpa = '/home/{}/meme/'.format(myusr)

# %%
ranres = random.choice(genres['result'])

# %%
ranres['imageUrl']
# Out:
# 'https://cdn.meme.am/cache/images/folder374/400x/3459374.jpg'

# %%
ranres['urlName']
# Out:
# 'Bad-Luck-Brian'

# %%
disnm = ranres['displayName']

# %%
response = requests.get(ranres['imageUrl'], stream=True)
with open('{}{}.jpg'.format(ranpa, disnm), 'wb') as out_file:
    shutil.copyfileobj(response.raw, out_file)
    del response

# %%
meeim = PIL.Image.open('{}{}.jpg'.format(ranpa, disnm))

# %%
Image('{}{}.jpg'.format(ranpa, disnm))

# %%
#meetest = PIL.Image.new("RGBA", (640,640), (255,255,255))
medraw = ImageDraw.Draw(meeim)
#font = ImageFont.truetype("/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf", 32)
#font = ImageFont.truetype("/home/wcm/Downloads/fashi954.ttf", 12)
fontwo = ImageFont.truetype('/usr/share/fonts/truetype/dejavu/DejaVuSansMono.ttf', 32)

medraw.text((10, 10), disnm, (0,0,0), font=fontwo)

# %%
meeim.save('/home/wcm/Downloads/success.jpg')

# %%
Image('/home/wcm/Downloads/success.jpg')

# %%
for gere in range(0,24):
    #print(genres['result'][gere]['displayName'])
    disnam.append(genres['result'][gere]['displayName'])
    #print(reqinst.json())
    #reins = (reqinst.json())
    #reqinst = requests.get('{}languageCode=en&pageIndex=0&pageSize=1&urlName={}'.format(selpo, genres['result'][gere]['displayName']))
    #reins = (reqinst.json())
    #print(reins)    
    #except Error:
    #    pass
    #else:
    #    print(reins['result'][0])
    #reins = (reqinst.json())
    #print(reins['result'][0])
    #if 'text0' in reins['result']:
    #    print(reins['result'][0])

# %%
#disnam

# %%
jodis = ' '.join(disnam)

# %%
''.join([str(jodis) for jodis in random.sample(jodis, len(jodis))])
# Out:
# ' eknmycfm sci hKeNe osbgo c yu oinDk A lriCeonrTWJur nSoo  d eFhe Taue tmgirekNeh oFs uotrae  raooc yFLialgTMyt Fiv rGb pu nSureLrmIA a cAnooncoFsggBrD   wcoulvtdglolMuP nl lkdgiyxrceo ourbnli SDerhirlanhK tue n tpsWTGuciacGCo Bodnt nonolrC oeef agkr rn son lssdeshG howltgrrrlnyTr  cupae  ipgea inaaib e  aeFiayorBnanregr u otygeilnhsorsF lNYeGF pl tewSyoS aa aPY nnlF  ueuOdaaGi tys BwtrNiUooYsu to lAa Gaecm ooes rogt  sP uwllgydtd UFKdnocxaooCllnonnoapanWP e dulir am batAsr oirF p kmFyobou PahicIl rhyIeloiBAWmrie tae u roWhlreasea rikec P tiB a s oai ISisrariWlcnom n htnyontltaauDl dens Csn e   i FuoDSGdnecipteySbgWtine emrsF oh drSGo  nfg yJ iTtre Piy  oeweWgoWoKcedbl lomWsnrur skorIl rMM A atprIWrngeOc oDy fseieYluP nveiAlelos l CWSpmhtvaG oc '

# %%
random.shuffle('wgewrgwgw')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1277-3ca69c866fcd> in <module>()
# ----> 1 random.shuffle('wgewrgwgw')
#
# /usr/lib/python3.4/random.py in shuffle(self, x, random)
#     270                 # pick an element in x[:i+1] with which to exchange x[i]
#     271                 j = randbelow(i+1)
# --> 272                 x[i], x[j] = x[j], x[i]
#     273         else:
#     274             _int = int
#
# TypeError: 'str' object does not support item assignment

# %%
tokens = nltk.word_tokenize(jodis)

# %%
#for tok in tokens:
    #print(tok.lower())
#    for tolo in tok.lower():
#        print(tolo)

# %%
meimg = requests.get('https://api.imgflip.com/get_memes')

# %%
mejsn = meimg.json()

# %%
lenme = len(mejsn['data']['memes'])

# %%
#PIL.Image

# %%
imgpath = ('/home/{}/fashion/'.format(myusr))

# %%
jurimg = PIL.Image.open(imgpath + 'fashion.jpg').convert('LA')

# %%
jurimg.save(imgpath + 'greyscale.png')

# %%
Image(imgpath + 'greyscale.png')

# %%
jurblack = PIL.Image.open(imgpath + 'greyscale.png')

# %%
jurother = PIL.Image.open(imgpath + 'fashion2.jpg')

# %%
Image(imgpath + 'fashion2.jpg')

# %%
jurthis = PIL.Image.open(imgpath + 'life.jpg')

# %%
jurother.size
# Out:
# (1000, 562)

# %%
jurthis.size
# Out:
# (1024, 768)

# %%
jurconv = jurthis.resize((1000, 562), PIL.Image.ANTIALIAS)

# %%
jurimg.size
# Out:
# (1000, 562)

# %%
jurother.mode
# Out:
# 'RGB'

# %%
jurimg.mode
# Out:
# 'LA'

# %%
jurthis.mode
# Out:
# 'RGB'

# %%
jurcol = jurimg.convert('RGB')

# %%
blenim = PIL.Image.blend(jurconv, jurcol, 0.7)

# %%
blenim.save(imgpath + 'blend.jpg')

# %%
Image(imgpath + 'blend.jpg')

# %%
mebig = meeim.resize((1000, 562), PIL.Image.ANTIALIAS)

# %%
#blenim = PIL.ImageFilter.GaussianBlur(jurblack)

# %%
#blenim.save(imgpath + 'blend.png')

# %%
ble = PIL.Image.open(imgpath + 'blend.jpg')

# %%
bleda = ble.getdata()

# %%
#out = PIL.Image.FLIP_LEFT_RIGHT(ble)

# %%
myrot = ble.rotate(180)

# %%
myrot.save(imgpath + 'rot.png')

# %%
blenow = PIL.Image.blend(myrot, mebig, 0.4)

# %%
blenow.save(imgpath + 'blendz.png')

# %%
Image(imgpath + 'blendz.png')

# %%
thble = ble.filter

# %%
PIL.ImageFilter.GaussianBlur
# Out:
# PIL.ImageFilter.GaussianBlur

# %%
blurred_image = blenow.filter(PIL.ImageFilter.BLUR)

# %%
blurred_image.save(imgpath + 'blur.png')

# %%
edit_image = blenow.filter(PIL.ImageFilter.SHARPEN)

# %%
edit_image.save(imgpath + 'sharp.png')

# %%
blz = PIL.Image.blend(blurred_image, edit_image, 0.5)

# %%
blz.save(imgpath + 'blshap.png')

# %%
artc = PIL.Image.open(imgpath + 'bellz.jpg')

# %%
img = artc.resize((1000, 562), PIL.Image.ANTIALIAS)

# %%
img.size
# Out:
# (1000, 562)

# %%
image = PIL.Image.new("RGBA", (1000,562), (255,255,255))

# %%
draw = ImageDraw.Draw(blenow)

# %%
font = ImageFont.truetype('/home/wcm/Downloads/fashi954.ttf', 12)

# %%
draw.text((10, 0), 'Fashion Blogger', (0,0,0), font=font)
#img_resized = image.resize((188,45), PIL.Image.ANTIALIAS)

# %%
image.save(imgpath + 'write.png')

# %%
#jodis

# %%
#for dis in disnam:
#    print(dis)

# %%
print(random.choice(disnam))

#for dis in disnam:
#    print(dis)
# Out:
# Joseph Ducreux

# %%
rcho = random.choice(genres['result'])

# %%
radisnam = rcho['displayName']

# %%
radisnam
# Out:
# 'Trollface'

# %%
image = PIL.Image.new("RGBA", (1000,562), (255,255,255))
draw = ImageDraw.Draw(image)
#font = ImageFont.truetype("/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf", 32)
#font = ImageFont.truetype("/home/wcm/Downloads/fashi954.ttf", 48)
fontwo = ImageFont.truetype('/usr/share/fonts/truetype/dejavu/DejaVuSansMono.ttf', 72)

draw.text((10, 10), radisnam, (0,0,0), font=fontwo)
draw.text((150, 450), 'Fashion Blogger', (0,0,0), font=fontwo)
#draw.text((150, 280), random.choice(disnam), (0,0,0), font=fontwo)

#draw.
#img_resized = image.resize((188,45), PIL.Image.ANTIALIAS)

# %%
image.save(imgpath + 'fashionblog.jpg')

# %%
img.mode
# Out:
# 'RGB'

# %%
undero = PIL.Image.open(imgpath + 'fashionblog.jpg')

# %%
undero.size
# Out:
# (1000, 562)

# %%
#undersixy = undero.resize((640,640), PIL.Image.ANTIALIAS)

# %%
artc.mode
# Out:
# 'RGB'

# %%
undersixy.mode
# Out:
# 'RGB'

# %%
#undersixyalp = undersixy.convert('RGBA')

# %%
#undersixyalp.size

# %%
img.mode
# Out:
# 'RGB'

# %%
undero.mode
# Out:
# 'RGB'

# %%
undero.size
# Out:
# (1000, 562)

# %%
img.size
# Out:
# (1000, 562)

# %%
bugger = PIL.Image.blend(img, undero, 0.5)

# %%
bugger.save(imgpath + 'undersixy.jpg')

# %%
#undersixy.save('/home/wcm/Downloads/undersixy.jpg')

# %%
undersixy.mode
# Out:
# 'RGB'

# %%
undersixy.size
# Out:
# (640, 640)

# %%
Image(imgpath + 'undersixy.jpg')

# %%
imapl = img.convert('RGBA')

# %%
blenow.save('/home/wcm/Downloads/alpha.png')

# %%
#img_resized.save('/home/wcm/Downloads/test.png')

# %%
image.save('/home/wcm/Downloads/bigsize.png')

# %%
img.mode
# Out:
# 'RGB'

# %%
imgrgb = img.convert('RGB')

# %%
imr = imgrgb.crop()

# %%
Image(imgpath + 'greyscale.png')

# %%
bugger = PIL.Image.blend(imgrgb, edit_image, 0.8)

# %%
bugger.save(imgpath + 'artc.png')

# %%
bwbug = bugger.convert('LA')

# %%
bwbug.save(imgpath + 'wbug.png')

# %%
bugger.mode
# Out:
# 'RGB'

# %%
bugra = bugger.convert('RGBA')

# %%
txtname = PIL.Image.blend(image, bugra, 0.5)

# %%
txtname.save(imgpath + 'txt.png')

# %%
Image(imgpath + "txt.png")

# %%
jurapl = jurimg.convert('RGBA')

# %%
blm = PIL.Image.blend(txtim,jurapl, 0.5)

# %%
blm.save(imgpath + 'blm.jpg')

# %%
Image(imgpath + 'blm.jpg')

# %%
blrot = blm.rotate(180)

# %%
txtim.mode
# Out:
# 'RGBA'

# %%
blrot.mode
# Out:
# 'RGBA'

# %%
txtim.size
# Out:
# (1000, 562)

# %%
blrot.size
# Out:
# (1000, 562)

# %%
blm = PIL.Image.blend(txtim,blrot, 0.5)

# %%
blm.save(imgpath + 'blmz.jpg')

# %%
undersixy.size
# Out:
# (640, 640)

# %%
undersixy.mode
# Out:
# 'RGB'

# %%
#alpsizy = undersixy.convert('RGBA')

# %%
underthere = undersixy.resize((1000, 562), PIL.Image.ANTIALIAS)

# %%
blrot.size
# Out:
# (1000, 562)

# %%
underthere.mode
# Out:
# 'RGB'

# %%
blrot.mode
# Out:
# 'RGBA'

# %%
blrz = blrot.convert('RGB')

# %%
bz = PIL.Image.blend(blrz, underthere, 0.2)

# %%
bz.save(imgpath + '/rot.jpg')

# %%
Image(imgpath + 'rot.jpg')

# %%
#__author__ = 'Robert'
#from images2gif import writeGif
#import os

#file_names = sorted((fn for fn in os.listdir('/home/wcm/j/') if fn.endswith('.png')))
#['animationframa.png', 'animationframb.png', 'animationframc.png', ...] "

#images = [PIL.Image.open(fn) for fn in file_names]

#print (writeGif.__doc__)
# writeGif(filename, images, duration=0.1, loops=0, dither=1)
#    Write an animated gif from the specified images.
#    images should be a list of numpy arrays of PIL images.
#    Numpy images of type float should have pixels between 0 and 1.
#    Numpy images of other types are expected to have values between 0 and 255.


#images.extend(reversed(images)) #infinit loop will go backwards and forwards.

#filename = "my_gif.GIF"
#writeGif(filename, images, duration=0.2)
#54 frames written
#
#Process finished with exit code 0

# %%
mejsn['data']['memes'][0]['url']
# Out:
# 'https://i.imgflip.com/1bij.jpg'

# %%
mepath = ('/home/{}/memeimg/'.format(myusr))

# %%
megif = ('/home/{}/memegif/'.format(myusr))

# %%
mepath
# Out:
# '/home/wcm/memeimg/'

# %%
reqmem = requests.get('http://api.duckduckgo.com/?q={}&format=json')

# %%
txtim = PIL.Image.open(imgpath + 'txt.png')

# %%
txtim.mode
# Out:
# 'RGBA'

# %%
txtim.size
# Out:
# (1000, 562)

# %%
Image(imgpath + 'txt.png')

# %%
for lem in range(0, lenme):
    print(mejsn['data']['memes'][lem]['name'])
    print(mejsn['data']['memes'][lem]['url'])  
    print(mejsn['data']['memes'][lem]['id'])
    response = requests.get((mejsn['data']['memes'][lem]['url']), stream=True)
    filid = (mejsn['data']['memes'][lem]['id'])
    menam = (mejsn['data']['memes'][lem]['name'])
    meplu = (menam.replace(' ', '+'))
    men = ('http://api.giphy.com/v1/gifs/search?q={}&api_key=dc6zaTOxFJmzC&limit=1&offset=0'.format(meplu))
    reme = requests.get(men)
    gifjsn = reme.json()
    gifurl = requests.get(gifjsn['data'][0]['images']['original']['url'])
    with open('{}{}.jpg'.format(megif, lem), 'wb') as out_file:
        shutil.copyfileobj(gifurl.raw, out_file)
        del response
    #print(gifjsn['data'][0]['images']['gif'])
    #reqmem = requests.get('http://api.duckduckgo.com/?q={}&format=json'.format(mejsn['data']['memes'][lem]['name']))
    #rejsn = reqmem.json()
    #print(rejsn['Entity'])
    #print(reqmem.json())
    #with open('{}{}.jpg'.format(mepath, filid), 'wb') as out_file:
    #    shutil.copyfileobj(response.raw, out_file)
    #    del response
# Out:
# One Does Not Simply
# https://i.imgflip.com/1bij.jpg
# 61579
# Batman Slapping Robin
# https://i.imgflip.com/9ehk.jpg
# 438680
# Ancient Aliens
# https://i.imgflip.com/26am.jpg
# 101470
# Futurama Fry
# https://i.imgflip.com/1bgw.jpg
# 61520
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     330             try:  # Python 2.7+, use buffering of HTTP responses
# --> 331                 httplib_response = conn.getresponse(buffering=True)
#     332             except TypeError:  # Python 2.6 and older
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# ConnectionResetError                      Traceback (most recent call last)
# ...
